# %% [markdown]
# ## Loading the Original Image

# %%
from matplotlib import pyplot as plt
import cv2

image_path = 'Einstein.jpg'
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

plt.imshow(original_image, cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
original_image.shape
# Out:
# (2666, 2000)

# %%
import numpy as np
import matplotlib.pyplot as plt

def apply_filter(original_image, filter):
    image_height, image_width = original_image.shape
    filter_height, filter_width = filter.shape
    filtered_image = np.zeros_like(original_image)
 
    for i in range(1, image_height - 1):
        for j in range(1, image_width - 1):
            region = original_image[i-1:i+2, j-1:j+2]
            filtered_value = np.sum(region * filter)
            filtered_image[i, j] = filtered_value

    return filtered_image

def display_images(original_image, filtered_image):
    plt.subplot(1, 2, 1)
    plt.imshow(original_image, cmap='gray')
    plt.title('Original Image')


    plt.subplot(1, 2, 2)
    plt.imshow(filtered_image, cmap='gray')
    plt.title('Filtered Image')

    plt.show()

# %%
f1 = np.array([[0, 0, 0],
               [0, 1, 0],
               [0, 0, 0]])

f2 = np.array([[0, 0, 0],
               [0, 0, 1],
               [0, 0, 0]])

f3 = np.array([[0, 0, 0],
               [1, 0, 0],
               [0, 0, 0]])

f4 = np.array([[0, 0, 1],
               [0, 0, 0],
               [0, 0, 0]])

f5 = np.array([[0, 0, 0],
               [0, 0, 0],
               [1, 0, 0]])

f2_1 = np.array([[1, 0,-1],
               [2, 0, -2],
               [1, 0, -1]])

f2_2 = np.array([[1,2,1],
               [0, 0, 0],
               [-1, -2, -1]])

f3_1 = np.array([[1/9,1/9,1/9],
               [1/9, 1/9, 1/9],
               [1/9, 1/9, 1/9]])

f3_2= np.array([[1/15,2/15,1/15],
               [2/15, 3/15, 2/15],
               [1/15, 2/15, 1/15]])

# %% [markdown]
# ## Applying First Filter

# %%
fi1=apply_filter(original_image, f1)
display_images(original_image,fi1)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi1
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 83, 82, ..., 27, 30,  0],
#        [ 0, 81, 80, ..., 25, 32,  0],
#        ...,
#        [ 0, 14, 13, ..., 38, 46,  0],
#        [ 0, 16, 15, ..., 56, 77,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %% [markdown]
# ## Applying 2nd Filter

# %%
fi2=apply_filter(original_image, f2)
display_images(original_image,fi2)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi2
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 82, 78, ..., 30, 33,  0],
#        [ 0, 80, 76, ..., 32, 38,  0],
#        ...,
#        [ 0, 13, 12, ..., 46, 68,  0],
#        [ 0, 15, 12, ..., 77, 93,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %% [markdown]
# ## Applying 3rd Filter

# %%
fi3=apply_filter(original_image, f3)
display_images(original_image,fi3)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi3
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 80, 83, ..., 25, 27,  0],
#        [ 0, 79, 81, ..., 22, 25,  0],
#        ...,
#        [ 0, 15, 14, ..., 46, 38,  0],
#        [ 0, 16, 16, ..., 45, 56,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %% [markdown]
# ## Applying 4th Filter

# %%
fi4=apply_filter(original_image, f4)
display_images(original_image,fi4)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi4
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 84, 79, ..., 26, 23,  0],
#        [ 0, 82, 78, ..., 30, 33,  0],
#        ...,
#        [ 0, 14, 12, ..., 41, 58,  0],
#        [ 0, 13, 12, ..., 46, 68,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %% [markdown]
# ## Applying 5th Filter

# %%
fi5=apply_filter(original_image, f5)
display_images(original_image,fi5)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi5
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 79, 81, ..., 22, 25,  0],
#        [ 0, 78, 78, ..., 23, 25,  0],
#        ...,
#        [ 0, 16, 16, ..., 45, 56,  0],
#        [ 0, 16, 16, ..., 46, 59,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %% [markdown]
# ## 2nd Question

# %% [markdown]
# ### 1st

# %%
fi2_1=apply_filter(original_image, f2_1)
display_images(original_image,fi2_1)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi2_1
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [  0, 247,  20, ..., 238, 236,   0],
#        [  0, 253,  18, ..., 226, 217,   0],
#        ...,
#        [  0,   7,  11, ..., 226, 137,   0],
#        [  0,   5,  14, ..., 155, 111,   0],
#        [  0,   0,   0, ...,   0,   0,   0]], dtype=uint8)

# %% [markdown]
# ### 2nd

# %%
fi2_2=apply_filter(original_image, f2_2)
display_images(original_image,fi2_2)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi2_2
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [  0,  11,  14, ...,   6, 232,   0],
#        [  0,  17,  18, ...,   8,   7,   0],
#        ...,
#        [  0, 253, 253, ..., 178, 129,   0],
#        [  0, 249, 250, ..., 177, 129,   0],
#        [  0,   0,   0, ...,   0,   0,   0]], dtype=uint8)

# %% [markdown]
# ## 3rd Question

# %% [markdown]
# ## 3_1

# %%
fi3_1=apply_filter(original_image, f3_1)
display_images(original_image,fi3_1)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi3_1
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 81, 80, ..., 27, 29,  0],
#        [ 0, 79, 78, ..., 26, 30,  0],
#        ...,
#        [ 0, 14, 13, ..., 47, 57,  0],
#        [ 0, 15, 13, ..., 55, 68,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %% [markdown]
# ## 3_2

# %%
fi3_2=apply_filter(original_image, f3_2)
display_images(original_image,fi3_2)

# %%
original_image
# Out:
# array([[ 80,  84,  84, ...,  28,  26,  23],
#        [ 80,  83,  82, ...,  27,  30,  33],
#        [ 79,  81,  80, ...,  25,  32,  38],
#        ...,
#        [ 15,  14,  13, ...,  38,  46,  68],
#        [ 16,  16,  15, ...,  56,  77,  93],
#        [ 16,  16,  15, ...,  59,  83, 100]], dtype=uint8)

# %%
fi3_2
# Out:
# array([[ 0,  0,  0, ...,  0,  0,  0],
#        [ 0, 81, 81, ..., 27, 29,  0],
#        [ 0, 80, 79, ..., 26, 30,  0],
#        ...,
#        [ 0, 14, 13, ..., 45, 55,  0],
#        [ 0, 15, 14, ..., 55, 70,  0],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)
